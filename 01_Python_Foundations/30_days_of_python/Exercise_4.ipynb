# %%
empty_list = []
lst1 = [1,2,3,4,5]
lst1.len()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 3
#       1 empty_list = []
#       2 lst1 = [1,2,3,4,5]
# ----> 3 lst1.len()
#
# AttributeError: 'list' object has no attribute 'len'
